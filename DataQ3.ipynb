# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
# !pip install koreanize-matplotlib

import koreanize_matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 10.8 MB/s eta 0:00:00
# ...

# %%
ratio = [7306, 6164, 3126, 2517, 40, 390]
labels = ['여가/휴식', '사업', '교육', '친구/친지', '종교/순례', '기타']

wed = {"width": 0.4}
exp = [0, 0, 0, 0, 0.6, 0]
title_font = {'fontsize': 14, 'fontweight': 'bold'}
plt.pie(ratio, labels=labels, autopct='%1.1f%%', pctdistance=0.8, startangle=260, shadow=True,
        colors = ['lightcoral','yellow','goldenrod','pink', 'brown', 'grey'], wedgeprops=wed, explode=exp
        )
plt.legend(labels, frameon = True, shadow = True, loc = 'upper right')
plt.title('여행자 방한 목적', loc = 'left', fontdict=title_font)
plt.show()
