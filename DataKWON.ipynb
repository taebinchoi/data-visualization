# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
# !pip install koreanize-matplotlib

import koreanize_matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 36.9 MB/s eta 0:00:00
# ...

# %%
data = {
    '지역': ['서울', '경기', '인천', '강원', '충청', '경상', '전라', '제주'],
    '인원수': [15967, 2982, 1955, 1406, 1513, 5863, 1508, 2544]
}

df = pd.DataFrame(data)
df_sorted = df.sort_values(by='인원수', ascending=False)

colors = ['#fa8072', '#cdb4db', '#cdb4db', '#cdb4db', '#cdb4db', '#cdb4db', '#cdb4db', '#cdb4db']
bar = plt.bar(df_sorted['지역'], df_sorted['인원수'], color=colors)

title_font = {'fontsize': 14, 'fontweight': 'bold'}
plt.title('한국 여행 중 방문 권역', fontdict=title_font, loc='left')
plt.xlabel('지역')

plt.legend(['인원수'], frameon = True, shadow = True, loc = 'upper right')

for rect in bar:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.0f' % height, ha='center', va='bottom', size = 9)

plt.tick_params(axis='x', direction='in', length=5, pad=6, labelsize=11)
plt.tick_params(axis='y', direction='in', length=5)

plt.show()
