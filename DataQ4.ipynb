# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
# !pip install koreanize-matplotlib

import koreanize_matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 20.0 MB/s eta 0:00:00
# ...

# %%
ratio = [17980, 825, 738]
labels = ['개별여행', 'AIR-TEL', '단체여행']

wed = {"width": 0.4}
exp = [0, 0.1, 0.2]
plt.pie(ratio, labels=labels, autopct='%1.1f%%', pctdistance=0.8, startangle=260, shadow=True,
        colors = ['lightcoral','yellow','goldenrod'], wedgeprops=wed, explode=exp
        )
plt.legend(labels, frameon = True, shadow = True, loc = 'lower right')
plt.title('여행자 여행 형태', loc = 'left')
plt.show()
